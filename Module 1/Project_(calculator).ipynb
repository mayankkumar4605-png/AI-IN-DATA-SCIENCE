# %%
#88Simple Calculator
num1=float(input("Enter number: "))     #first number
num2=float(input("Enter number: "))     #Second number
op = input("Enter operation: + - * /")  #operation
def calculation(a,b):

 if op == "+":                                #checking condition for operation
   print(f"Sum of numbers: {a+b}")
 elif op == "-":
   print(f"Subtraction of numbers: {a-b}")
 elif op == "*":
   print(f"Multiplication of numbers: {a*b}")
 elif op == "/":
   if op == 0:
     print("Error: Division by zero")         #error checking if diving by 0
 else:
    print(f"Division of numbers: {a/b}")

calculation(num1,num2)
# Out:
# Enter number: 4
# Enter number: 5
# Enter operation: + - * /+
# Sum of numbers: 9.0
